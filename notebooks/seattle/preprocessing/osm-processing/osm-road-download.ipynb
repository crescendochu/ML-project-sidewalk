# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
# %matplotlib inline
import seaborn as sns; sns.set_theme(color_codes=True)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors
import warnings
warnings.filterwarnings('ignore')
import osmnx as ox

# %%
#north, south, east, west
G = ox.graph_from_bbox(47.7345314, 47.49544907, -122.23896027, -122.41842651, network_type='drive')

# %%
nodes, edges = ox.utils_graph.graph_to_gdfs(G)
edges.head()
# Out:
#                                                                      osmid  \
# u        v          key
# 29445663 335444348  0                                              4634309
#          29485641   0                                            608025479
# 29447670 3391701882 0              [40416106, 4635028, 607798222, 4634847]
#          4240312871 0    [40416108, 981053037, 981053038, 424636848, 10...
# 29449421 9567450119 0                   [1052610031, 446010581, 143178399]
#
#                          oneway      lanes     ref                    highway  \
# u        v          key
# 29445663 335444348  0      True          2  WA 520              motorway_link
#          29485641   0      True          3     I 5                   motorway
# 29447670 3391701882 0      True  [1, 3, 2]     NaN              motorway_link
#          4240312871 0      True          2  WA 520                   motorway
# 29449421 9567450119 0      True          2  WA 520  [motorway, motorway_link]
#
#                                  maxspeed   length  \
# u        v          key
# 29445663 335444348  0              60 mph  636.024
#          29485641   0              60 mph  688.835
# 29447670 3391701882 0                 NaN  401.979
#          4240312871 0    [60 mph, 40 mph]  740.948
# 29449421 9567450119 0    [60 mph, 50 mph]  715.929
#
#                                                                   geometry  \
# u        v          key
# 29445663 335444348  0    LINESTRING (-122.32263 47.63854, -122.32251 47...
#          29485641   0    LINESTRING (-122.32263 47.63854, -122.32257 47...
# 29447670 3391701882 0    LINESTRING (-122.30891 47.64331, -122.30805 47...
#          4240312871 0    LINESTRING (-122.30891 47.64331, -122.30663 47...
# 29449421 9567450119 0    LINESTRING (-122.30916 47.64334, -122.30949 47...
#
#                           bridge                           name tunnel  \
# u        v          key
# 29445663 335444348  0        NaN                            NaN    NaN
#          29485641   0        NaN                            NaN    NaN
# 29447670 3391701882 0    viaduct                            NaN    NaN
#          4240312871 0    viaduct  [Portage Bay Viaduct, WA 520]    yes
# 29449421 9567450119 0    viaduct            Portage Bay Viaduct    NaN
#
#                         junction width access
# u        v          key
# 29445663 335444348  0        NaN   NaN    NaN
#          29485641   0        NaN   NaN    NaN
# 29447670 3391701882 0        NaN   NaN    NaN
#          4240312871 0        NaN   NaN    NaN
# 29449421 9567450119 0        NaN   NaN    NaN

# %%
streets = edges.explode('highway')

# %%
streets['highway'].unique()
# Out:
# array(['motorway_link', 'motorway', 'secondary', 'primary',
#        'secondary_link', 'residential', 'tertiary', 'unclassified',
#        'primary_link', 'trunk_link', 'trunk', 'living_street',
#        'tertiary_link', 'busway', 'crossing', 'stop_line'], dtype=object)

# %%
# select only highway, osmid and geometry
streets = streets[['highway', 'osmid', 'geometry']]

# %%
# reset index and explode osmid
streets = streets.explode('osmid').reset_index(drop=True)

# %%
streets
# Out:
#              highway       osmid  \
# 0      motorway_link     4634309
# 1           motorway   608025479
# 2      motorway_link    40416106
# 3      motorway_link     4635028
# 4      motorway_link   607798222
# ...              ...         ...
# 62595    residential   340365566
# 62596    residential  1138304083
# 62597    residential     6399535
# 62598    residential  1138304083
# 62599    residential     6399535
#
#                                                 geometry
# 0      LINESTRING (-122.32263 47.63854, -122.32251 47...
# 1      LINESTRING (-122.32263 47.63854, -122.32257 47...
# 2      LINESTRING (-122.30891 47.64331, -122.30805 47...
# 3      LINESTRING (-122.30891 47.64331, -122.30805 47...
# 4      LINESTRING (-122.30891 47.64331, -122.30805 47...
# ...                                                  ...
# 62595  LINESTRING (-122.34106 47.63658, -122.34134 47...
# 62596  LINESTRING (-122.30830 47.49990, -122.30830 47...
# 62597  LINESTRING (-122.30830 47.49933, -122.30741 47...
# 62598  LINESTRING (-122.30830 47.49933, -122.30830 47...
# 62599  LINESTRING (-122.30830 47.49933, -122.30890 47...
#
# [62600 rows x 3 columns]

# %%
#save to shapefile
streets.to_file('data/seattle-osm-roads/seattle-osm-roads.shp')

# %%
#streets.explore(tiles='cartodbpositron', column='highway')

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
# %matplotlib inline
import seaborn as sns; sns.set_theme(color_codes=True)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt

# %%
#read in intersections data
intersections = gpd.read_file('../../../data/oradell/osm/osm-intersections/osm-intersections-cleaned/osm-intersections-cleaned.shp')

# %%
intersections
# Out:
#         way_type    osm_id                    geometry
# 0        primary  11566257  POINT (-74.02981 40.96929)
# 1       tertiary  11570206  POINT (-74.04022 40.96285)
# 2    residential  11574526  POINT (-74.04594 40.96277)
# 3        primary  11574182  POINT (-74.03099 40.95720)
# 4    residential  11566257  POINT (-74.03446 40.95761)
# ..           ...       ...                         ...
# 232  residential  11566257  POINT (-74.03456 40.95714)
# 233  residential  11569682  POINT (-74.04101 40.95230)
# 234     tertiary  61313136  POINT (-74.03930 40.96260)
# 235  residential  11581697  POINT (-74.03070 40.94495)
# 236  residential  11573489  POINT (-74.03633 40.95812)
#
# [237 rows x 3 columns]

# %%
#read in labels
labels = gpd.read_file('../../../data/oradell/processed-labels/labels_raw_oradell/labels_raw_oradell.shp')

# %%
labels
# Out:
#        audit_task  label_id              gsv_panora      label_type  severity  \
# 0               7         9  8AsY4nlOJQAo8P5YYaEjzA        CurbRamp       1.0
# 1               7        10  8AsY4nlOJQAo8P5YYaEjzA      NoSidewalk       5.0
# 2               7        11  8AsY4nlOJQAo8P5YYaEjzA        CurbRamp       1.0
# 3               7        12  8AsY4nlOJQAo8P5YYaEjzA      NoSidewalk       5.0
# 4               7        13  8AsY4nlOJQAo8P5YYaEjzA       Crosswalk       1.0
# ...           ...       ...                     ...             ...       ...
# 12129        2194     13096  28tGbhCsMyFUsKRs7-jp_A      NoCurbRamp       2.0
# 12130        2194     13097  28tGbhCsMyFUsKRs7-jp_A        Obstacle       4.0
# 12131        2194     13098  5zDLTjYdw6hQhfsXppE0cA  SurfaceProblem       1.0
# 12132        2202     13099  WkdNrR64GZUC1V_at1pxyA      NoCurbRamp       NaN
# 12133        2202     13100  WkdNrR64GZUC1V_at1pxyA      NoCurbRamp       NaN
#
#       correct  high_quali              gsv_pano_1  zoom     heading  \
# 0           1           1  8AsY4nlOJQAo8P5YYaEjzA     2  309.035706
# 1           1           1  8AsY4nlOJQAo8P5YYaEjzA     2  303.232147
# 2           1           1  8AsY4nlOJQAo8P5YYaEjzA     2  266.714294
# 3           1           1  8AsY4nlOJQAo8P5YYaEjzA     2  270.821442
# 4           1           1  8AsY4nlOJQAo8P5YYaEjzA     2  284.392853
# ...       ...         ...                     ...   ...         ...
# 12129       1           1  28tGbhCsMyFUsKRs7-jp_A     2  189.401779
# 12130    None           1  28tGbhCsMyFUsKRs7-jp_A     2  189.401779
# 12131       1           1  5zDLTjYdw6hQhfsXppE0cA     2   77.437500
# 12132    None           0  WkdNrR64GZUC1V_at1pxyA     1  178.687500
# 12133       0           0  WkdNrR64GZUC1V_at1pxyA     1   12.000000
#
#            pitch  photograph  photogra_1  \
# 0     -15.723214  108.536644   -0.496017
# 1     -13.580358  108.536644   -0.496017
# 2     -12.330358  108.536644   -0.496017
# 3     -11.616072  108.536644   -0.496017
# 4     -13.758928  108.536644   -0.496017
# ...          ...         ...         ...
# 12129 -10.892858  287.290100   -2.176155
# 12130 -10.892858  287.290100   -2.176155
# 12131 -23.928572  287.278870   -2.803400
# 12132  -8.625000  281.559601   -2.859410
# 12133 -22.312500  281.559601   -2.859410
#
#                                     user_id        lat        lng  \
# 0      503d2482-420f-454e-8118-aac2d22592aa  40.945518 -74.034111
# 1      503d2482-420f-454e-8118-aac2d22592aa  40.945541 -74.034142
# 2      503d2482-420f-454e-8118-aac2d22592aa  40.945435 -74.034157
# 3      503d2482-420f-454e-8118-aac2d22592aa  40.945446 -74.034203
# 4      503d2482-420f-454e-8118-aac2d22592aa  40.945473 -74.034142
# ...                                     ...        ...        ...
# 12129  528eb1d6-e20e-4fb9-81c9-0c06b9e2852f  40.954376 -74.030624
# 12130  528eb1d6-e20e-4fb9-81c9-0c06b9e2852f  40.954391 -74.030617
# 12131  528eb1d6-e20e-4fb9-81c9-0c06b9e2852f  40.954624 -74.030891
# 12132  0cfe6980-35ac-4cdd-a2df-cbee02531406  40.969189 -74.029976
# 12133  0cfe6980-35ac-4cdd-a2df-cbee02531406  40.969387 -74.029930
#
#                          geometry
# 0      POINT (-74.03411 40.94552)
# 1      POINT (-74.03414 40.94554)
# 2      POINT (-74.03416 40.94543)
# 3      POINT (-74.03420 40.94545)
# 4      POINT (-74.03414 40.94547)
# ...                           ...
# 12129  POINT (-74.03062 40.95438)
# 12130  POINT (-74.03062 40.95439)
# 12131  POINT (-74.03089 40.95462)
# 12132  POINT (-74.02998 40.96919)
# 12133  POINT (-74.02993 40.96939)
#
# [12134 rows x 17 columns]

# %%
#select the curb ramps and non-curb ramps
curb = labels.loc[(labels['label_type']=='CurbRamp')]
no_curb = labels.loc[(labels['label_type']=='NoCurbRamp')]
#concatenate the two dataframes
all_curbs = pd.concat([curb, no_curb])
all_curbs
# Out:
#        audit_task  label_id              gsv_panora  label_type  severity  \
# 0               7         9  8AsY4nlOJQAo8P5YYaEjzA    CurbRamp       1.0
# 2               7        11  8AsY4nlOJQAo8P5YYaEjzA    CurbRamp       1.0
# 5               7        14  8AsY4nlOJQAo8P5YYaEjzA    CurbRamp       1.0
# 6               7        15  8AsY4nlOJQAo8P5YYaEjzA    CurbRamp       1.0
# 18              7        27  7pDHlqVEtaIL-DbjuR-Bwg    CurbRamp       1.0
# ...           ...       ...                     ...         ...       ...
# 12099        2176     13043  o9ZptmEg7JNnJaPNdj6Djw  NoCurbRamp       1.0
# 12100        2176     13044  IMvapJmUNJSNs64yB5Xefg  NoCurbRamp       4.0
# 12129        2194     13096  28tGbhCsMyFUsKRs7-jp_A  NoCurbRamp       2.0
# 12132        2202     13099  WkdNrR64GZUC1V_at1pxyA  NoCurbRamp       NaN
# 12133        2202     13100  WkdNrR64GZUC1V_at1pxyA  NoCurbRamp       NaN
#
#       correct  high_quali              gsv_pano_1  zoom     heading  \
# 0           1           1  8AsY4nlOJQAo8P5YYaEjzA     2  309.035706
# 2           1           1  8AsY4nlOJQAo8P5YYaEjzA     2  266.714294
# 5           1           1  8AsY4nlOJQAo8P5YYaEjzA     1   45.428570
# 6           1           1  8AsY4nlOJQAo8P5YYaEjzA     1  151.178574
# 18          1           1  7pDHlqVEtaIL-DbjuR-Bwg     1  289.680267
# ...       ...         ...                     ...   ...         ...
# 12099    None           1  o9ZptmEg7JNnJaPNdj6Djw     3  185.555801
# 12100       0           1  IMvapJmUNJSNs64yB5Xefg     3  204.165176
# 12129       1           1  28tGbhCsMyFUsKRs7-jp_A     2  189.401779
# 12132    None           0  WkdNrR64GZUC1V_at1pxyA     1  178.687500
# 12133       0           0  WkdNrR64GZUC1V_at1pxyA     1   12.000000
#
#            pitch  photograph  photogra_1  \
# 0     -15.723214  108.536644   -0.496017
# 2     -12.330358  108.536644   -0.496017
# 5     -33.785713  108.536644   -0.496017
# 6     -35.000000  108.536644   -0.496017
# 18    -35.000000  198.439819   -0.389183
# ...          ...         ...         ...
# 12099 -16.437500  289.178223   -0.541770
# 12100 -16.671875  289.768250   -0.903824
# 12129 -10.892858  287.290100   -2.176155
# 12132  -8.625000  281.559601   -2.859410
# 12133 -22.312500  281.559601   -2.859410
#
#                                     user_id        lat        lng  \
# 0      503d2482-420f-454e-8118-aac2d22592aa  40.945518 -74.034111
# 2      503d2482-420f-454e-8118-aac2d22592aa  40.945435 -74.034157
# 5      503d2482-420f-454e-8118-aac2d22592aa  40.945480 -74.033981
# 6      503d2482-420f-454e-8118-aac2d22592aa  40.945415 -74.034012
# 18     503d2482-420f-454e-8118-aac2d22592aa  40.945045 -74.034348
# ...                                     ...        ...        ...
# 12099  ce60454f-5d40-4649-a17a-562a46c57519  40.952457 -74.041946
# 12100  ce60454f-5d40-4649-a17a-562a46c57519  40.952419 -74.041824
# 12129  528eb1d6-e20e-4fb9-81c9-0c06b9e2852f  40.954376 -74.030624
# 12132  0cfe6980-35ac-4cdd-a2df-cbee02531406  40.969189 -74.029976
# 12133  0cfe6980-35ac-4cdd-a2df-cbee02531406  40.969387 -74.029930
#
#                          geometry
# 0      POINT (-74.03411 40.94552)
# 2      POINT (-74.03416 40.94543)
# 5      POINT (-74.03398 40.94548)
# 6      POINT (-74.03401 40.94542)
# 18     POINT (-74.03435 40.94505)
# ...                           ...
# 12099  POINT (-74.04195 40.95246)
# 12100  POINT (-74.04182 40.95242)
# 12129  POINT (-74.03062 40.95438)
# 12132  POINT (-74.02998 40.96919)
# 12133  POINT (-74.02993 40.96939)
#
# [2240 rows x 17 columns]

# %%
#change crs to 3424
intersections = intersections.to_crs(epsg=3424)
all_curbs = all_curbs.to_crs(epsg=3424)

# %%
#spatial join curb ramps to intersections
curb_to_intersection = all_curbs.sjoin_nearest(intersections, distance_col='distance')
curb_to_intersection
# Out:
#       audit_task  label_id              gsv_panora  label_type  severity  \
# 0              7         9  8AsY4nlOJQAo8P5YYaEjzA    CurbRamp       1.0
# 2              7        11  8AsY4nlOJQAo8P5YYaEjzA    CurbRamp       1.0
# 5              7        14  8AsY4nlOJQAo8P5YYaEjzA    CurbRamp       1.0
# 6              7        15  8AsY4nlOJQAo8P5YYaEjzA    CurbRamp       1.0
# 6704        1112      7151  Tu5MN4i-9qVTV2F-Hv7cMw    CurbRamp       1.0
# ...          ...       ...                     ...         ...       ...
# 9058        1473      9565  tUsbb4nL0LOheTRgLJAN8Q  NoCurbRamp       5.0
# 9059        1473      9568  67eCLVxhycjAUrjOcn-kCg  NoCurbRamp       5.0
# 9060        1473      9569  7ODwBJGAV-bcR1--zgkrOg  NoCurbRamp       5.0
# 9849        1541     10368  bIgUdhWsbWApbZfxVH0Jtg  NoCurbRamp       3.0
# 9852        1541     10373  bIgUdhWsbWApbZfxVH0Jtg  NoCurbRamp       3.0
#
#      correct  high_quali              gsv_pano_1  zoom     heading      pitch  \
# 0          1           1  8AsY4nlOJQAo8P5YYaEjzA     2  309.035706 -15.723214
# 2          1           1  8AsY4nlOJQAo8P5YYaEjzA     2  266.714294 -12.330358
# 5          1           1  8AsY4nlOJQAo8P5YYaEjzA     1   45.428570 -33.785713
# 6          1           1  8AsY4nlOJQAo8P5YYaEjzA     1  151.178574 -35.000000
# 6704       1           1  Tu5MN4i-9qVTV2F-Hv7cMw     1  336.937500 -34.250000
# ...      ...         ...                     ...   ...         ...        ...
# 9058    None           1  tUsbb4nL0LOheTRgLJAN8Q     1  196.000000 -32.000000
# 9059       1           1  67eCLVxhycjAUrjOcn-kCg     1  288.000000 -34.000000
# 9060    None           1  7ODwBJGAV-bcR1--zgkrOg     1  288.000000 -34.000000
# 9849       0           0  bIgUdhWsbWApbZfxVH0Jtg     1  173.562500 -27.500000
# 9852    None           0  bIgUdhWsbWApbZfxVH0Jtg     1  256.437500 -28.250000
#
#       photograph  photogra_1                               user_id        lat  \
# 0     108.536644   -0.496017  503d2482-420f-454e-8118-aac2d22592aa  40.945518
# 2     108.536644   -0.496017  503d2482-420f-454e-8118-aac2d22592aa  40.945435
# 5     108.536644   -0.496017  503d2482-420f-454e-8118-aac2d22592aa  40.945480
# 6     108.536644   -0.496017  503d2482-420f-454e-8118-aac2d22592aa  40.945415
# 6704  198.414276    1.677094  2d7e45f5-3656-4aae-9a09-14addfa80d22  40.945431
# ...          ...         ...                                   ...        ...
# 9058   17.427141    0.288208  799265af-987c-4d6e-8d2e-6d450b293c78  40.959541
# 9059  195.258347    0.755150  799265af-987c-4d6e-8d2e-6d450b293c78  40.959454
# 9060   53.332340    0.229187  799265af-987c-4d6e-8d2e-6d450b293c78  40.959560
# 9849   24.840570   -1.635925  179e5217-cf98-4e48-8011-241b9435dcdc  40.960552
# 9852   24.840570   -1.635925  179e5217-cf98-4e48-8011-241b9435dcdc  40.960617
#
#             lng                       geometry  index_right     way_type  \
# 0    -74.034111  POINT (620819.055 769691.165)          165  residential
# 2    -74.034157  POINT (620806.573 769660.523)          165  residential
# 5    -74.033981  POINT (620854.956 769677.459)          165  residential
# 6    -74.034012  POINT (620846.652 769653.788)          165  residential
# 6704 -74.034157  POINT (620806.580 769659.134)          165  residential
# ...         ...                            ...          ...          ...
# 9058 -74.035828  POINT (620317.740 774797.311)          160  residential
# 9059 -74.035873  POINT (620305.267 774765.280)          160  residential
# 9060 -74.035820  POINT (620319.810 774804.271)          160  residential
# 9849 -74.044205  POINT (618002.270 775153.411)           30  residential
# 9852 -74.044365  POINT (617957.900 775176.806)           30  residential
#
#         osm_id   distance
# 0     11566869  16.196217
# 2     11566869  28.692549
# 5     11566869  25.954706
# 6     11566869  30.273827
# 6704  11566869  29.572597
# ...        ...        ...
# 9058  11578670  42.202088
# 9059  11578670  32.859523
# 9060  11578670  47.628010
# 9849  11570114  35.648957
# 9852  11570114  56.376510
#
# [2240 rows x 21 columns]

# %%
#select only label_id, highwa, distance
curb_to_intersection = curb_to_intersection[['label_id','distance']]

# %%
#rename highway to way_type, and distance to distance_to_intersection
curb_to_intersection = curb_to_intersection.rename(columns={'distance':'distance_to_intersection'})
curb_to_intersection.head()
# Out:
#       label_id  distance_to_intersection
# 0            9                 16.196217
# 2           11                 28.692549
# 5           14                 25.954706
# 6           15                 30.273827
# 6704      7151                 29.572597

# %%
#merge labels and intersection_d
df = labels[['label_id']].merge(curb_to_intersection, on='label_id', how='left')
#fill in missing values with 0
df = df.fillna(0)
df
# Out:
#        label_id  distance_to_intersection
# 0             9                 16.196217
# 1            10                  0.000000
# 2            11                 28.692549
# 3            12                  0.000000
# 4            13                  0.000000
# ...         ...                       ...
# 12129     13096                117.545556
# 12130     13097                  0.000000
# 12131     13098                  0.000000
# 12132     13099                 58.873892
# 12133     13100                 48.427510
#
# [12134 rows x 2 columns]

# %%
df.to_csv('../../../data/oradell/features/distance_to_intersection.csv', index=False)

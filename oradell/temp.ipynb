# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
# %matplotlib inline
import seaborn as sns; sns.set_theme(color_codes=True)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors
import warnings
warnings.filterwarnings('ignore')
from scipy.cluster.hierarchy import linkage, fcluster
from scipy.spatial.distance import pdist
import sys
from haversine import haversine

# %%
#read csv file
labels = pd.read_csv('data/processed-labels/labels_all_oradell.csv')

# %%
labels
# Out:
#        audit_task_id  label_id       gsv_panorama_id_x      label_type  \
# 0                  7         9  8AsY4nlOJQAo8P5YYaEjzA        CurbRamp
# 1                  7        10  8AsY4nlOJQAo8P5YYaEjzA      NoSidewalk
# 2                  7        11  8AsY4nlOJQAo8P5YYaEjzA        CurbRamp
# 3                  7        12  8AsY4nlOJQAo8P5YYaEjzA      NoSidewalk
# 4                  7        13  8AsY4nlOJQAo8P5YYaEjzA       Crosswalk
# ...              ...       ...                     ...             ...
# 12129           2194     13096  28tGbhCsMyFUsKRs7-jp_A      NoCurbRamp
# 12130           2194     13097  28tGbhCsMyFUsKRs7-jp_A        Obstacle
# 12131           2194     13098  5zDLTjYdw6hQhfsXppE0cA  SurfaceProblem
# 12132           2202     13099  WkdNrR64GZUC1V_at1pxyA      NoCurbRamp
# 12133           2202     13100  WkdNrR64GZUC1V_at1pxyA      NoCurbRamp
#
#        severity correct  high_quality_user  \
# 0           1.0    True               True
# 1           5.0    True               True
# 2           1.0    True               True
# 3           5.0    True               True
# 4           1.0    True               True
# ...         ...     ...                ...
# 12129       2.0    True               True
# 12130       4.0     NaN               True
# 12131       1.0    True               True
# 12132       NaN     NaN              False
# 12133       NaN   False              False
#
#                                             geometry       gsv_panorama_id_y  \
# 0      POINT (-74.03411102294922 40.945518493652344)  8AsY4nlOJQAo8P5YYaEjzA
# 1       POINT (-74.03414154052734 40.94554138183594)  8AsY4nlOJQAo8P5YYaEjzA
# 2         POINT (-74.0341567993164 40.9454345703125)  8AsY4nlOJQAo8P5YYaEjzA
# 3         POINT (-74.0342025756836 40.9454460144043)  8AsY4nlOJQAo8P5YYaEjzA
# 4      POINT (-74.03414154052734 40.945472717285156)  8AsY4nlOJQAo8P5YYaEjzA
# ...                                              ...                     ...
# 12129  POINT (-74.03062438964844 40.954376220703125)  28tGbhCsMyFUsKRs7-jp_A
# 12130    POINT (-74.0306167602539 40.95439147949219)  28tGbhCsMyFUsKRs7-jp_A
# 12131   POINT (-74.03089141845703 40.95462417602539)  5zDLTjYdw6hQhfsXppE0cA
# 12132   POINT (-74.02997589111328 40.96918869018555)  WkdNrR64GZUC1V_at1pxyA
# 12133    POINT (-74.0299301147461 40.96938705444336)  WkdNrR64GZUC1V_at1pxyA
#
#        zoom     heading      pitch  photographer_heading  photographer_pitch  \
# 0         2  309.035706 -15.723214            108.536644           -0.496017
# 1         2  303.232147 -13.580358            108.536644           -0.496017
# 2         2  266.714294 -12.330358            108.536644           -0.496017
# 3         2  270.821442 -11.616072            108.536644           -0.496017
# 4         2  284.392853 -13.758928            108.536644           -0.496017
# ...     ...         ...        ...                   ...                 ...
# 12129     2  189.401779 -10.892858            287.290100           -2.176155
# 12130     2  189.401779 -10.892858            287.290100           -2.176155
# 12131     2   77.437500 -23.928572            287.278870           -2.803400
# 12132     1  178.687500  -8.625000            281.559601           -2.859410
# 12133     1   12.000000 -22.312500            281.559601           -2.859410
#
#                                     user_id        lat        lng
# 0      503d2482-420f-454e-8118-aac2d22592aa  40.945518 -74.034111
# 1      503d2482-420f-454e-8118-aac2d22592aa  40.945541 -74.034142
# 2      503d2482-420f-454e-8118-aac2d22592aa  40.945435 -74.034157
# 3      503d2482-420f-454e-8118-aac2d22592aa  40.945446 -74.034203
# 4      503d2482-420f-454e-8118-aac2d22592aa  40.945473 -74.034142
# ...                                     ...        ...        ...
# 12129  528eb1d6-e20e-4fb9-81c9-0c06b9e2852f  40.954376 -74.030624
# 12130  528eb1d6-e20e-4fb9-81c9-0c06b9e2852f  40.954391 -74.030617
# 12131  528eb1d6-e20e-4fb9-81c9-0c06b9e2852f  40.954624 -74.030891
# 12132  0cfe6980-35ac-4cdd-a2df-cbee02531406  40.969189 -74.029976
# 12133  0cfe6980-35ac-4cdd-a2df-cbee02531406  40.969387 -74.029930
#
# [12134 rows x 17 columns]

# %%
#read csv file
test = pd.read_csv('data/processed-labels/test_set_oradell.csv')

# %%
test
# Out:
#       audit_task_id  label_id       gsv_panorama_id_x  label_type  severity  \
# 0                 7         9  8AsY4nlOJQAo8P5YYaEjzA    CurbRamp       1.0
# 1                 7        10  8AsY4nlOJQAo8P5YYaEjzA  NoSidewalk       5.0
# 2                 7        11  8AsY4nlOJQAo8P5YYaEjzA    CurbRamp       1.0
# 3                 7        12  8AsY4nlOJQAo8P5YYaEjzA  NoSidewalk       5.0
# 4                 7        13  8AsY4nlOJQAo8P5YYaEjzA   Crosswalk       1.0
# ...             ...       ...                     ...         ...       ...
# 4138           1628     11753  SNQ1WaQPKcAkvTOTAtULJA    Obstacle       2.0
# 4139           1648     12092  F_sesLbDcaUyjG7w_nwdzg    Obstacle       4.0
# 4140           1718     12539  QSi-X0zwaqMR5rhs09kYig    CurbRamp       1.0
# 4141           2005     12837  IZzqo_5Sjr3UZtRaV83-qA    CurbRamp       2.0
# 4142           2005     12843  tsBRN0xhgLv8BRkOVGdbtg    CurbRamp       NaN
#
#      correct  high_quality_user  \
# 0       True               True
# 1       True               True
# 2       True               True
# 3       True               True
# 4       True               True
# ...      ...                ...
# 4138    True               True
# 4139    True               True
# 4140    True               True
# 4141    True               True
# 4142    True               True
#
#                                            geometry       gsv_panorama_id_y  \
# 0     POINT (-74.03411102294922 40.945518493652344)  8AsY4nlOJQAo8P5YYaEjzA
# 1      POINT (-74.03414154052734 40.94554138183594)  8AsY4nlOJQAo8P5YYaEjzA
# 2        POINT (-74.0341567993164 40.9454345703125)  8AsY4nlOJQAo8P5YYaEjzA
# 3        POINT (-74.0342025756836 40.9454460144043)  8AsY4nlOJQAo8P5YYaEjzA
# 4     POINT (-74.03414154052734 40.945472717285156)  8AsY4nlOJQAo8P5YYaEjzA
# ...                                             ...                     ...
# 4138    POINT (-74.0452880859375 40.96165466308594)  SNQ1WaQPKcAkvTOTAtULJA
# 4139   POINT (-74.03170013427734 40.94500732421875)  F_sesLbDcaUyjG7w_nwdzg
# 4140   POINT (-74.01839447021484 40.95423889160156)  QSi-X0zwaqMR5rhs09kYig
# 4141   POINT (-74.0303955078125 40.953975677490234)  IZzqo_5Sjr3UZtRaV83-qA
# 4142   POINT (-74.03047943115234 40.95360565185547)  tsBRN0xhgLv8BRkOVGdbtg
#
#       zoom     heading      pitch  photographer_heading  photographer_pitch  \
# 0        2  309.035706 -15.723214            108.536644           -0.496017
# 1        2  303.232147 -13.580358            108.536644           -0.496017
# 2        2  266.714294 -12.330358            108.536644           -0.496017
# 3        2  270.821442 -11.616072            108.536644           -0.496017
# 4        2  284.392853 -13.758928            108.536644           -0.496017
# ...    ...         ...        ...                   ...                 ...
# 4138     2  137.830353 -11.071428            108.567726            0.086418
# 4139     3   36.669643  -8.265625             19.918083            1.928528
# 4140     1   90.812500 -14.000000            338.763458            0.073710
# 4141     1  129.375000 -15.875000            341.502716           -1.179410
# 4142     1  141.410721 -16.125000             10.155263            1.508070
#
#                                    user_id        lat        lng  cluster_id  \
# 0     503d2482-420f-454e-8118-aac2d22592aa  40.945518 -74.034111         442
# 1     503d2482-420f-454e-8118-aac2d22592aa  40.945541 -74.034142         321
# 2     503d2482-420f-454e-8118-aac2d22592aa  40.945435 -74.034157         467
# 3     503d2482-420f-454e-8118-aac2d22592aa  40.945446 -74.034203         324
# 4     503d2482-420f-454e-8118-aac2d22592aa  40.945473 -74.034142         159
# ...                                    ...        ...        ...         ...
# 4138  2d7e45f5-3656-4aae-9a09-14addfa80d22  40.961655 -74.045288          72
# 4139  e86fdc72-c79d-4cdc-b5b2-8ef4859141d2  40.945007 -74.031700          63
# 4140  52b661f5-2ecd-4733-acc4-dad4b32e319e  40.954239 -74.018394          44
# 4141  b92705c0-b6b0-42b4-8ff1-f376c0920987  40.953976 -74.030396          29
# 4142  b92705c0-b6b0-42b4-8ff1-f376c0920987  40.953606 -74.030479          37
#
#       count  false_positive   distance  tag_list  description  tag_count  \
# 0         5               0   8.785378       0.0          0.0        0.0
# 1         6               0  13.819353       1.0          0.0        1.0
# 2         5               0  16.290317       0.0          0.0        0.0
# 3         5               0  24.869158       1.0          0.0        1.0
# 4        10               0   9.900008       0.0          0.0        0.0
# ...     ...             ...        ...       ...          ...        ...
# 4138     10               0  19.647431       1.0          0.0        1.0
# 4139      7               0  21.717830       1.0          0.0        1.0
# 4140     10               0  11.304296       0.0          0.0        0.0
# 4141     13               0  25.783018       1.0          0.0        1.0
# 4142      8               0  14.626877       1.0          0.0        1.0
#
#          way_type  intersection_distance  verified
# 0     residential              16.318492         1
# 1              -1              -1.000000         1
# 2     residential              28.909092         1
# 3              -1              -1.000000         1
# 4              -1              -1.000000         1
# ...           ...                    ...       ...
# 4138           -1              -1.000000         1
# 4139           -1              -1.000000         1
# 4140  residential              31.171581         1
# 4141  residential              34.700662         1
# 4142      service              28.743836         1
#
# [4143 rows x 27 columns]
